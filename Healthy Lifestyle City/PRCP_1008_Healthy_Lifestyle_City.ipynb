# %% [markdown]
# # <b>PRCP-1008
# # <b>HEALTHY LIFESTYLE CITY

# %% [markdown]
# # <b>BUSINESS PROBLEM

# %% [markdown]
# ## <b>PROBLEM CONTEXT
# <b>
#
# - WITH THE HEALTHY LIFESTYLE CITY DATASET WE NEED TO CLUSTER HEALTHY LIFESTYLE CITY INTO CERTAIN GROUP.

# %% [markdown]
# ## <b>CONTENT
# <b>
#
# - HEALTHY LIFESTYLE CITIES IN 2021 WITH DIFFERENT FEATURES.

# %% [markdown]
# # <b>TASK 1
# #### <b>PREPARE A COMPLETE DATA ANALYSIS REPORT ON THE GIVEN DATA.
# # <b>Task 2
# #### <b>EXPLORE FEATURES AND CLUSTER CITIES BASED ON THEIR ATTRTIBUDES.

# %% [markdown]
# ## <b>FEATURES:
# <b>
#
# - City
# - Rank
# - Sunshine hours(City)
# - Cost of a bottle of water(City)
# - Obesity levels(Country)
# - Life expectancy(years) (Country)
# - Pollution
# - Annual avg. hours worked
# - Happiness levels(Country)
# - Outdoor activities(City)
# - Number of take out places(City)
# - Cost of a monthly gym membership(City)

# %% [markdown]
# ### <b>TYPES OF MACHINE LEARNING PROBLEM.
# - <b>Clustering is an unsupervised learning technique where the goal is to group similar data points together without predefined labels<br>
# ### <b>ALGORITHM USES FOR CLASSIFICATION
# <b>
#
# - K-Means

# %% [markdown]
# ## <b>FEATURE ANALYSIS
#
#
# - <b>City</b><br>
#   Total 44 healthy life-style city in 2021.
#
# - <b>Rank</b><br>
# Rank of healty life-style city.
#
# - <b>Sunshine hours(City)</b><br>
# Sunshine hours is a measure of the amount of direct sunshine a site receives(per year)
#
# - <b>Cost of a bottle of water(City)</b><br>
# Cost of water bottel in pound.
#
# - <b>Obesity levels(Country)</b><br>
# A condition characterised by abnormal or excessive fat accumulation.
#
# - <b>Life expectancy(years) (Country)</b><br>
# Life expentancy of healthy lifestyle city.
#
# - <b>Pollution</b><br>
# The Comprehensive Environmental Pollution Index (CEPI) scores of the critically polluted industrial clusters/areas. The index captures the various dimensions of environment including air, water and land.
#
# - <b>Annual avg. hours worked</b><br>
# Working hours (avg 1,730 hours per year, or 36.04 hours per week).
#
# - <b>Happiness levels(Country)</b><br>
# It is based on national happiness as well as based on respondent ratings of their own lives, which the report also correlates with various (quality of) life factors.
#
# - <b>Outdoor activities(City)</b><br>
# Activity that occurs in an unroofed area as part of a permitted use on a lot and any outdoor display of material & Outdoor activity means an athletic, entertainment or similar activity.(count of outdoor activities in per year).
#
# - <b>Number of take out places(City)</b><br>
# Total take-out places in city.
#
# - <b>Cost of a monthly gym membership(City)</b><br>
# Monthly cost of gym in pound.

# %% [markdown]
# # <b>TASK 1
# #### <b>PREPARE A COMPLETE DATA ANALYSIS REPORT ON THE GIVEN DATA.

# %% [markdown]
# ##  <b>IMPORTING LIBRARIES AND LOAD DATA

# %%
### import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset:
data = pd.read_csv('healthy_lifestyle_city_2021.csv',na_values=['-'])

# %%
data
# Out:
#                 City  Rank  Sunshine hours(City)  \
# 0          Amsterdam     1                1858.0
# 1             Sydney     2                2636.0
# 2             Vienna     3                1884.0
# 3          Stockholm     4                1821.0
# 4         Copenhagen     5                1630.0
# 5           Helsinki     6                1662.0
# 6            Fukuoka     7                2769.0
# 7             Berlin     8                1626.0
# 8          Barcelona     9                2591.0
# 9          Vancouver    10                1938.0
# 10         Melbourne    11                2363.0
# 11           Beijing    12                2671.0
# 12           Bangkok    13                2624.0
# 13      Buenos Aires    14                2525.0
# 14           Toronto    15                2066.0
# 15            Madrid    16                2769.0
# 16           Jakarta    17                2983.0
# 17             Seoul    18                2066.0
# 18         Frankfurt    19                1662.0
# 19            Geneva    20                   NaN
# 20          Tel Aviv    21                3311.0
# 21          Istanbul    22                2218.0
# 22             Cairo    23                3542.0
# 23            Taipei    24                1405.0
# 24       Los Angeles    25                3254.0
# 25            Mumbai    26                2584.0
# 26            Boston    27                2634.0
# 27            Dublin    28                1453.0
# 28             Tokyo    29                1877.0
# 29           Chicago    30                2508.0
# 30         Hong Kong    31                1836.0
# 31          Shanghai    32                1776.0
# 32          Brussels    33                1546.0
# 33     San Francisco    34                3062.0
# 34             Paris    35                1662.0
# 35         Sao Paulo    36                2003.0
# 36            Zurich    37                1566.0
# 37            London    38                1633.0
# 38      Johannesburg    39                3124.0
# 39             Milan    40                1915.0
# 40  Washington, D.C.    41                2528.0
# 41          New York    42                2535.0
# 42            Moscow    43                1901.0
# 43       Mexico City    44                2555.0
#
#    Cost of a bottle of water(City) Obesity levels(Country)  \
# 0                            £1.92                  20.40%
# 1                            £1.48                  29.00%
# 2                            £1.94                  20.10%
# 3                            £1.72                  20.60%
# 4                            £2.19                  19.70%
# 5                            £1.60                  22.20%
# 6                            £0.78                   4.30%
# 7                            £1.55                  22.30%
# 8                            £1.19                  23.80%
# 9                            £1.08                  29.40%
# 10                           £1.57                  29.00%
# 11                           £0.26                   6.20%
# 12                           £0.22                  10.00%
# 13                           £0.57                  28.30%
# 14                           £1.09                  29.40%
# 15                           £1.30                  23.80%
# 16                           £0.21                   6.90%
# 17                           £0.59                   4.70%
# 18                           £1.95                  22.30%
# 19                           £2.62                  19.50%
# 20                           £1.63                  26.10%
# 21                           £0.15                  32.10%
# 22                           £0.16                  32.00%
# 23                           £0.57                   6.20%
# 24                           £1.52                  36.20%
# 25                           £0.15                   3.90%
# 26                           £1.39                  36.20%
# 27                           £1.40                  25.30%
# 28                           £0.76                   4.30%
# 29                           £1.20                  36.20%
# 30                           £0.75                   6.20%
# 31                           £0.29                   6.20%
# 32                           £2.11                  22.10%
# 33                           £1.60                  36.20%
# 34                           £1.95                  21.60%
# 35                           £0.44                  22.10%
# 36                           £3.20                  19.50%
# 37                           £1.16                  27.80%
# 38                           £0.59                  28.30%
# 39                           £1.15                  19.90%
# 40                           £1.45                  36.20%
# 41                           £1.32                  36.20%
# 42                           £0.41                  23.10%
# 43                           £0.45                  28.90%
#
#     Life expectancy(years) (Country)  Pollution(Index score) (City)  \
# 0                               81.2                          30.93
# 1                               82.1                          26.86
# 2                               81.0                          17.33
# 3                               81.8                          19.63
# 4                               79.8                          21.24
# 5                               80.4                          13.08
# 6                               83.2                            NaN
# 7                               80.6                          39.41
# 8                               82.2                          65.19
# 9                               81.7                          24.26
# 10                              82.1                          25.90
# 11                              75.4                          85.43
# 12                              74.1                          76.64
# 13                              75.9                          52.64
# 14                              81.7                          37.83
# 15                              82.2                          52.68
# 16                              68.5                          84.39
# 17                              81.3                          57.82
# 18                              80.6                          37.78
# 19                              82.6                          27.25
# 20                              81.9                          47.28
# 21                              74.7                          69.49
# 22                              70.7                          91.74
# 23                              75.4                          49.32
# 24                              78.8                          66.07
# 25                              67.3                          82.84
# 26                              78.8                          27.03
# 27                              80.5                          40.07
# 28                              83.2                          42.84
# 29                              78.8                          43.33
# 30                              75.4                          67.46
# 31                              75.4                          77.40
# 32                              80.4                          62.67
# 33                              78.8                          47.36
# 34                              81.8                          65.10
# 35                              73.9                          79.78
# 36                              82.6                          17.31
# 37                              80.4                          58.91
# 38                              56.3                          61.83
# 39                              82.7                          67.19
# 40                              78.8                          39.18
# 41                              78.8                          57.36
# 42                              69.5                          57.63
# 43                              76.4                          82.78
#
#     Annual avg. hours worked  Happiness levels(Country)  \
# 0                     1434.0                       7.44
# 1                     1712.0                       7.22
# 2                     1501.0                       7.29
# 3                     1452.0                       7.35
# 4                     1380.0                       7.64
# 5                     1540.0                       7.80
# 6                     1644.0                       5.87
# 7                     1386.0                       7.07
# 8                     1686.0                       6.40
# 9                     1670.0                       7.23
# 10                    1712.0                       7.22
# 11                       NaN                       5.12
# 12                       NaN                       5.99
# 13                       NaN                       5.97
# 14                    1670.0                       7.23
# 15                    1686.0                       6.40
# 16                       NaN                       5.28
# 17                    1967.0                       5.87
# 18                    1386.0                       7.07
# 19                    1557.0                       7.56
# 20                    1898.0                       7.12
# 21                    1832.0                       5.13
# 22                       NaN                       4.15
# 23                       NaN                       5.12
# 24                    1779.0                       6.94
# 25                       NaN                       3.57
# 26                    1779.0                       6.94
# 27                    1772.0                       7.09
# 28                    1644.0                       5.87
# 29                    1779.0                       6.94
# 30                       NaN                       5.51
# 31                       NaN                       5.12
# 32                    1583.0                       6.86
# 33                    1779.0                       6.94
# 34                    1505.0                       6.66
# 35                       NaN                       6.37
# 36                    1557.0                       7.56
# 37                    1538.0                       7.16
# 38                       NaN                       4.81
# 39                    1718.0                       6.38
# 40                    1779.0                       6.94
# 41                    1779.0                       6.94
# 42                    1965.0                       5.54
# 43                    2137.0                       6.46
#
#     Outdoor activities(City)  Number of take out places(City)  \
# 0                        422                             1048
# 1                        406                             1103
# 2                        132                             1008
# 3                        129                              598
# 4                        154                              523
# 5                        113                              309
# 6                         35                              539
# 7                        254                             1729
# 8                        585                             2344
# 9                        218                              788
# 10                       243                              813
# 11                       223                              261
# 12                       377                             1796
# 13                       246                             1435
# 14                       174                             1656
# 15                       216                             2491
# 16                       114                              833
# 17                       144                              389
# 18                        23                              551
# 19                        44                              444
# 20                       139                              420
# 21                       419                              934
# 22                       323                              250
# 23                       134                              717
# 24                       223                             1439
# 25                       187                             1183
# 26                        88                              588
# 27                       159                              659
# 28                       387                             5802
# 29                       171                             1320
# 30                       277                             1257
# 31                       108                              346
# 32                        55                              988
# 33                       242                             1031
# 34                       331                             4363
# 35                       158                             3355
# 36                        69                              538
# 37                       433                             6417
# 38                       194                              492
# 39                       110                             2396
# 40                        83                              744
# 41                       359                             3081
# 42                       322                             3206
# 43                       192                             1313
#
#    Cost of a monthly gym membership(City)
# 0                                  £34.90
# 1                                  £41.66
# 2                                  £25.74
# 3                                  £37.31
# 4                                  £32.53
# 5                                  £35.23
# 6                                  £55.87
# 7                                  £26.11
# 8                                  £37.80
# 9                                  £31.04
# 10                                 £36.89
# 11                                 £38.62
# 12                                 £50.03
# 13                                 £22.45
# 14                                 £32.64
# 15                                 £34.54
# 16                                 £29.94
# 17                                 £43.03
# 18                                 £39.01
# 19                                 £70.00
# 20                                 £58.31
# 21                                 £16.97
# 22                                 £23.25
# 23                                 £34.76
# 24                                 £32.00
# 25                                 £19.54
# 26                                 £46.27
# 27                                 £37.35
# 28                                 £70.82
# 29                                 £41.14
# 30                                 £57.95
# 31                                 £44.68
# 32                                 £25.34
# 33                                 £65.13
# 34                                 £35.93
# 35                                 £16.07
# 36                                 £73.11
# 37                                 £42.71
# 38                                 £24.28
# 39                                 £53.49
# 40                                 £65.99
# 41                                 £64.66
# 42                                 £31.40
# 43                                 £41.99

# %%
# For displaying all feature from dataset:
pd.pandas.set_option('display.max_columns', None)

# %% [markdown]
# ## <b>BASIC CHECKS

# %%
# Top 5 Records
data.head()
# Out:
#          City  Rank  Sunshine hours(City) Cost of a bottle of water(City)  \
# 0   Amsterdam     1                1858.0                           £1.92
# 1      Sydney     2                2636.0                           £1.48
# 2      Vienna     3                1884.0                           £1.94
# 3   Stockholm     4                1821.0                           £1.72
# 4  Copenhagen     5                1630.0                           £2.19
#
#   Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0                  20.40%                              81.2
# 1                  29.00%                              82.1
# 2                  20.10%                              81.0
# 3                  20.60%                              81.8
# 4                  19.70%                              79.8
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 0                          30.93                    1434.0
# 1                          26.86                    1712.0
# 2                          17.33                    1501.0
# 3                          19.63                    1452.0
# 4                          21.24                    1380.0
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0                       7.44                       422
# 1                       7.22                       406
# 2                       7.29                       132
# 3                       7.35                       129
# 4                       7.64                       154
#
#    Number of take out places(City) Cost of a monthly gym membership(City)
# 0                             1048                                 £34.90
# 1                             1103                                 £41.66
# 2                             1008                                 £25.74
# 3                              598                                 £37.31
# 4                              523                                 £32.53

# %%
# Bottom 5 Records
data.tail
# Out:
# <bound method NDFrame.tail of                 City  Rank  Sunshine hours(City)  \
# 0          Amsterdam     1                1858.0
# 1             Sydney     2                2636.0
# 2             Vienna     3                1884.0
# 3          Stockholm     4                1821.0
# 4         Copenhagen     5                1630.0
# 5           Helsinki     6                1662.0
# 6            Fukuoka     7                2769.0
# 7             Berlin     8                1626.0
# 8          Barcelona     9                2591.0
# 9          Vancouver    10                1938.0
# 10         Melbourne    11                2363.0
# 11           Beijing    12                2671.0
# 12           Bangkok    13                2624.0
# 13      Buenos Aires    14                2525.0
# 14           Toronto    15                2066.0
# 15            Madrid    16                2769.0
# 16           Jakarta    17                2983.0
# 17             Seoul    18                2066.0
# 18         Frankfurt    19                1662.0
# 19            Geneva    20                   NaN
# 20          Tel Aviv    21                3311.0
# 21          Istanbul    22                2218.0
# 22             Cairo    23                3542.0
# 23            Taipei    24                1405.0
# 24       Los Angeles    25                3254.0
# 25            Mumbai    26                2584.0
# 26            Boston    27                2634.0
# 27            Dublin    28                1453.0
# 28             Tokyo    29                1877.0
# 29           Chicago    30                2508.0
# 30         Hong Kong    31                1836.0
# 31          Shanghai    32                1776.0
# 32          Brussels    33                1546.0
# 33     San Francisco    34                3062.0
# 34             Paris    35                1662.0
# 35         Sao Paulo    36                2003.0
# 36            Zurich    37                1566.0
# 37            London    38                1633.0
# 38      Johannesburg    39                3124.0
# 39             Milan    40                1915.0
# 40  Washington, D.C.    41                2528.0
# 41          New York    42                2535.0
# 42            Moscow    43                1901.0
# 43       Mexico City    44                2555.0
#
#    Cost of a bottle of water(City) Obesity levels(Country)  \
# 0                            £1.92                  20.40%
# 1                            £1.48                  29.00%
# 2                            £1.94                  20.10%
# 3                            £1.72                  20.60%
# 4                            £2.19                  19.70%
# 5                            £1.60                  22.20%
# 6                            £0.78                   4.30%
# 7                            £1.55                  22.30%
# 8                            £1.19                  23.80%
# 9                            £1.08                  29.40%
# 10                           £1.57                  29.00%
# 11                           £0.26                   6.20%
# 12                           £0.22                  10.00%
# 13                           £0.57                  28.30%
# 14                           £1.09                  29.40%
# 15                           £1.30                  23.80%
# 16                           £0.21                   6.90%
# 17                           £0.59                   4.70%
# 18                           £1.95                  22.30%
# 19                           £2.62                  19.50%
# 20                           £1.63                  26.10%
# 21                           £0.15                  32.10%
# 22                           £0.16                  32.00%
# 23                           £0.57                   6.20%
# 24                           £1.52                  36.20%
# 25                           £0.15                   3.90%
# 26                           £1.39                  36.20%
# 27                           £1.40                  25.30%
# 28                           £0.76                   4.30%
# 29                           £1.20                  36.20%
# 30                           £0.75                   6.20%
# 31                           £0.29                   6.20%
# 32                           £2.11                  22.10%
# 33                           £1.60                  36.20%
# 34                           £1.95                  21.60%
# 35                           £0.44                  22.10%
# 36                           £3.20                  19.50%
# 37                           £1.16                  27.80%
# 38                           £0.59                  28.30%
# 39                           £1.15                  19.90%
# 40                           £1.45                  36.20%
# 41                           £1.32                  36.20%
# 42                           £0.41                  23.10%
# 43                           £0.45                  28.90%
#
#     Life expectancy(years) (Country)  Pollution(Index score) (City)  \
# 0                               81.2                          30.93
# 1                               82.1                          26.86
# 2                               81.0                          17.33
# 3                               81.8                          19.63
# 4                               79.8                          21.24
# 5                               80.4                          13.08
# 6                               83.2                            NaN
# 7                               80.6                          39.41
# 8                               82.2                          65.19
# 9                               81.7                          24.26
# 10                              82.1                          25.90
# 11                              75.4                          85.43
# 12                              74.1                          76.64
# 13                              75.9                          52.64
# 14                              81.7                          37.83
# 15                              82.2                          52.68
# 16                              68.5                          84.39
# 17                              81.3                          57.82
# 18                              80.6                          37.78
# 19                              82.6                          27.25
# 20                              81.9                          47.28
# 21                              74.7                          69.49
# 22                              70.7                          91.74
# 23                              75.4                          49.32
# 24                              78.8                          66.07
# 25                              67.3                          82.84
# 26                              78.8                          27.03
# 27                              80.5                          40.07
# 28                              83.2                          42.84
# 29                              78.8                          43.33
# 30                              75.4                          67.46
# 31                              75.4                          77.40
# 32                              80.4                          62.67
# 33                              78.8                          47.36
# 34                              81.8                          65.10
# 35                              73.9                          79.78
# 36                              82.6                          17.31
# 37                              80.4                          58.91
# 38                              56.3                          61.83
# 39                              82.7                          67.19
# 40                              78.8                          39.18
# 41                              78.8                          57.36
# 42                              69.5                          57.63
# 43                              76.4                          82.78
#
#     Annual avg. hours worked  Happiness levels(Country)  \
# 0                     1434.0                       7.44
# 1                     1712.0                       7.22
# 2                     1501.0                       7.29
# 3                     1452.0                       7.35
# 4                     1380.0                       7.64
# 5                     1540.0                       7.80
# 6                     1644.0                       5.87
# 7                     1386.0                       7.07
# 8                     1686.0                       6.40
# 9                     1670.0                       7.23
# 10                    1712.0                       7.22
# 11                       NaN                       5.12
# 12                       NaN                       5.99
# 13                       NaN                       5.97
# 14                    1670.0                       7.23
# 15                    1686.0                       6.40
# 16                       NaN                       5.28
# 17                    1967.0                       5.87
# 18                    1386.0                       7.07
# 19                    1557.0                       7.56
# 20                    1898.0                       7.12
# 21                    1832.0                       5.13
# 22                       NaN                       4.15
# 23                       NaN                       5.12
# 24                    1779.0                       6.94
# 25                       NaN                       3.57
# 26                    1779.0                       6.94
# 27                    1772.0                       7.09
# 28                    1644.0                       5.87
# 29                    1779.0                       6.94
# 30                       NaN                       5.51
# 31                       NaN                       5.12
# 32                    1583.0                       6.86
# 33                    1779.0                       6.94
# 34                    1505.0                       6.66
# 35                       NaN                       6.37
# 36                    1557.0                       7.56
# 37                    1538.0                       7.16
# 38                       NaN                       4.81
# 39                    1718.0                       6.38
# 40                    1779.0                       6.94
# 41                    1779.0                       6.94
# 42                    1965.0                       5.54
# 43                    2137.0                       6.46
#
#     Outdoor activities(City)  Number of take out places(City)  \
# 0                        422                             1048
# 1                        406                             1103
# 2                        132                             1008
# 3                        129                              598
# 4                        154                              523
# 5                        113                              309
# 6                         35                              539
# 7                        254                             1729
# 8                        585                             2344
# 9                        218                              788
# 10                       243                              813
# 11                       223                              261
# 12                       377                             1796
# 13                       246                             1435
# 14                       174                             1656
# 15                       216                             2491
# 16                       114                              833
# 17                       144                              389
# 18                        23                              551
# 19                        44                              444
# 20                       139                              420
# 21                       419                              934
# 22                       323                              250
# 23                       134                              717
# 24                       223                             1439
# 25                       187                             1183
# 26                        88                              588
# 27                       159                              659
# 28                       387                             5802
# 29                       171                             1320
# 30                       277                             1257
# 31                       108                              346
# 32                        55                              988
# 33                       242                             1031
# 34                       331                             4363
# 35                       158                             3355
# 36                        69                              538
# 37                       433                             6417
# 38                       194                              492
# 39                       110                             2396
# 40                        83                              744
# 41                       359                             3081
# 42                       322                             3206
# 43                       192                             1313
#
#    Cost of a monthly gym membership(City)
# 0                                  £34.90
# 1                                  £41.66
# 2                                  £25.74
# 3                                  £37.31
# 4                                  £32.53
# 5                                  £35.23
# 6                                  £55.87
# 7                                  £26.11
# 8                                  £37.80
# 9                                  £31.04
# 10                                 £36.89
# 11                                 £38.62
# 12                                 £50.03
# 13                                 £22.45
# 14                                 £32.64
# 15                                 £34.54
# 16                                 £29.94
# 17                                 £43.03
# 18                                 £39.01
# 19                                 £70.00
# 20                                 £58.31
# 21                                 £16.97
# 22                                 £23.25
# 23                                 £34.76
# 24                                 £32.00
# 25                                 £19.54
# 26                                 £46.27
# 27                                 £37.35
# 28                                 £70.82
# 29                                 £41.14
# 30                                 £57.95
# 31                                 £44.68
# 32                                 £25.34
# 33                                 £65.13
# 34                                 £35.93
# 35                                 £16.07
# 36                                 £73.11
# 37                                 £42.71
# 38                                 £24.28
# 39                                 £53.49
# 40                                 £65.99
# 41                                 £64.66
# 42                                 £31.40
# 43                                 £41.99  >

# %%
# Check shape of dataset
data.shape
# Out:
# (44, 12)

# %% [markdown]
# <b>In data their are 44 observation and 12 feature.

# %%
data.describe()
# Out:
#             Rank  Sunshine hours(City)  Life expectancy(years) (Country)  \
# count  44.000000             43.000000                          44.00000
# mean   22.500000           2245.860465                          78.17500
# std    12.845233            567.403719                           5.30437
# min     1.000000           1405.000000                          56.30000
# 25%    11.750000           1798.500000                          75.40000
# 50%    22.500000           2066.000000                          80.40000
# 75%    33.250000           2629.000000                          81.80000
# max    44.000000           3542.000000                          83.20000
#
#        Pollution(Index score) (City)  Annual avg. hours worked  \
# count                      43.000000                 33.000000
# mean                       51.122326               1672.909091
# std                        21.856190                179.626933
# min                        13.080000               1380.000000
# 25%                        34.355000               1540.000000
# 50%                        52.640000               1686.000000
# 75%                        66.630000               1779.000000
# max                        91.740000               2137.000000
#
#        Happiness levels(Country)  Outdoor activities(City)  \
# count                  44.000000                 44.000000
# mean                    6.435000                213.977273
# std                     0.991202                127.190297
# min                     3.570000                 23.000000
# 25%                     5.870000                125.250000
# 50%                     6.900000                189.500000
# 75%                     7.175000                288.250000
# max                     7.800000                585.000000
#
#        Number of take out places(City)
# count                        44.000000
# mean                       1443.113636
# std                        1388.803270
# min                         250.000000
# 25%                         548.000000
# 50%                         998.000000
# 75%                        1674.250000
# max                        6417.000000

# %% [markdown]
# <b>Observation
# - Constant column is not present in dataset

# %% [markdown]
# ## <b>EXPLOTARY DATA ANALYSIS

# %% [markdown]
# #### <b>1)UNIVARIATE ANALYSIS

# %%
# remove special characters
data = data.replace('[\£,%]','',regex=True)

# %%
data.head()
# Out:
#          City  Rank  Sunshine hours(City) Cost of a bottle of water(City)  \
# 0   Amsterdam     1                1858.0                            1.92
# 1      Sydney     2                2636.0                            1.48
# 2      Vienna     3                1884.0                            1.94
# 3   Stockholm     4                1821.0                            1.72
# 4  Copenhagen     5                1630.0                            2.19
#
#   Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0                   20.40                              81.2
# 1                   29.00                              82.1
# 2                   20.10                              81.0
# 3                   20.60                              81.8
# 4                   19.70                              79.8
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 0                          30.93                    1434.0
# 1                          26.86                    1712.0
# 2                          17.33                    1501.0
# 3                          19.63                    1452.0
# 4                          21.24                    1380.0
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0                       7.44                       422
# 1                       7.22                       406
# 2                       7.29                       132
# 3                       7.35                       129
# 4                       7.64                       154
#
#    Number of take out places(City) Cost of a monthly gym membership(City)
# 0                             1048                                  34.90
# 1                             1103                                  41.66
# 2                             1008                                  25.74
# 3                              598                                  37.31
# 4                              523                                  32.53

# %%
import sweetviz as sv

univariate_report = sv.analyze(data)
univariate_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# <b>Observation
# - Rank:- healthy life-style city rank range between 1 to 44.
# - Sunshie-city:- the maximun sunshine hours is 3542 and lowest sunshine hours is 1405.
# - Life expentancy:- the average life expentancy of healty life-style city is 78.2 year.
# - pollution index score :- the range of pollution index score between 13.1 to 91.7.
# - happiness level:- average of happiness level of healthy life-style city is 6.44.
# - outdoor activities :- maximum 585 & minimum 23 outdoor activities in healty life-style city.
# - No of take out places:- the take out places range between 250 to 6417.

# %% [markdown]
# #### <b>2)BIVARIATE ANALYSIS

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# %matplotlib inline

av = AutoViz_Class()

filename = ""
sep = ","
dft = av.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=data,
    header=0,
    verbose=0,
    lowess=False,
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
    #save_plot_dir="eda_plots",
    #chart_format='html'
    chart_format='png'

)
display(dft)
# Out:
# Shape of your Data Set loaded: (44, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     12 Predictors classified...
#         4 variable(s) removed since they were ID or low-information variables
#     All variables classified into correct types.
# <style type="text/css">
# #T_74c20_row0_col0, #T_74c20_row0_col2, #T_74c20_row0_col3, #T_74c20_row0_col4, #T_74c20_row0_col5, #T_74c20_row1_col0, #T_74c20_row1_col2, #T_74c20_row1_col3, #T_74c20_row1_col4, #T_74c20_row1_col5, #T_74c20_row2_col0, #T_74c20_row2_col2, #T_74c20_row2_col3, #T_74c20_row2_col4, #T_74c20_row2_col5, #T_74c20_row3_col0, #T_74c20_row3_col2, #T_74c20_row3_col3, #T_74c20_row3_col4, #T_74c20_row3_col5, #T_74c20_row4_col0, #T_74c20_row4_col2, #T_74c20_row4_col3, #T_74c20_row4_col4, #T_74c20_row4_col5, #T_74c20_row5_col0, #T_74c20_row5_col2, #T_74c20_row5_col3, #T_74c20_row5_col4, #T_74c20_row5_col5, #T_74c20_row6_col0, #T_74c20_row6_col2, #T_74c20_row6_col3, #T_74c20_row6_col4, #T_74c20_row6_col5, #T_74c20_row7_col0, #T_74c20_row7_col2, #T_74c20_row7_col3, #T_74c20_row7_col4, #T_74c20_row7_col5, #T_74c20_row8_col0, #T_74c20_row8_col2, #T_74c20_row8_col3, #T_74c20_row8_col4, #T_74c20_row8_col5, #T_74c20_row9_col0, #T_74c20_row9_col2, #T_74c20_row9_col3, #T_74c20_row9_col4, #T_74c20_row9_col5, #T_74c20_row10_col0, #T_74c20_row10_col2, #T_74c20_row10_col3, #T_74c20_row10_col4, #T_74c20_row10_col5, #T_74c20_row11_col0, #T_74c20_row11_col2, #T_74c20_row11_col3, #T_74c20_row11_col4, #T_74c20_row11_col5 {
#   font-family: Segoe UI;
# }
# #T_74c20_row0_col1, #T_74c20_row1_col1, #T_74c20_row3_col1, #T_74c20_row4_col1, #T_74c20_row5_col1, #T_74c20_row8_col1, #T_74c20_row9_col1, #T_74c20_row10_col1, #T_74c20_row11_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_74c20_row2_col1, #T_74c20_row6_col1 {
#   background-color: #fee6da;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_74c20_row7_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_74c20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74c20_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_74c20_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_74c20_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_74c20_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_74c20_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_74c20_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74c20_level0_row0" class="row_heading level0 row0" >City</th>
#       <td id="T_74c20_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_74c20_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_74c20_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_74c20_row0_col3" class="data row0 col3" ></td>
#       <td id="T_74c20_row0_col4" class="data row0 col4" ></td>
#       <td id="T_74c20_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row1" class="row_heading level0 row1" >Rank</th>
#       <td id="T_74c20_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_74c20_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_74c20_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_74c20_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_74c20_row1_col4" class="data row1 col4" >44.000000</td>
#       <td id="T_74c20_row1_col5" class="data row1 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row2" class="row_heading level0 row2" >Sunshine hours(City)</th>
#       <td id="T_74c20_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_74c20_row2_col1" class="data row2 col1" >2.272727</td>
#       <td id="T_74c20_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_74c20_row2_col3" class="data row2 col3" >1405.000000</td>
#       <td id="T_74c20_row2_col4" class="data row2 col4" >3542.000000</td>
#       <td id="T_74c20_row2_col5" class="data row2 col5" >1 missing values. Impute them with mean, median, mode, or a constant value such as 123.</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row3" class="row_heading level0 row3" >Cost of a bottle of water(City)</th>
#       <td id="T_74c20_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_74c20_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_74c20_row3_col2" class="data row3 col2" >88</td>
#       <td id="T_74c20_row3_col3" class="data row3 col3" ></td>
#       <td id="T_74c20_row3_col4" class="data row3 col4" ></td>
#       <td id="T_74c20_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row4" class="row_heading level0 row4" >Obesity levels(Country)</th>
#       <td id="T_74c20_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_74c20_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_74c20_row4_col2" class="data row4 col2" >63</td>
#       <td id="T_74c20_row4_col3" class="data row4 col3" ></td>
#       <td id="T_74c20_row4_col4" class="data row4 col4" ></td>
#       <td id="T_74c20_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row5" class="row_heading level0 row5" >Life expectancy(years) (Country)</th>
#       <td id="T_74c20_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_74c20_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_74c20_row5_col2" class="data row5 col2" >NA</td>
#       <td id="T_74c20_row5_col3" class="data row5 col3" >56.300000</td>
#       <td id="T_74c20_row5_col4" class="data row5 col4" >83.200000</td>
#       <td id="T_74c20_row5_col5" class="data row5 col5" >Column has 1 outliers greater than upper bound (91.40) or lower than lower bound(65.80). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row6" class="row_heading level0 row6" >Pollution(Index score) (City)</th>
#       <td id="T_74c20_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_74c20_row6_col1" class="data row6 col1" >2.272727</td>
#       <td id="T_74c20_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_74c20_row6_col3" class="data row6 col3" >13.080000</td>
#       <td id="T_74c20_row6_col4" class="data row6 col4" >91.740000</td>
#       <td id="T_74c20_row6_col5" class="data row6 col5" >1 missing values. Impute them with mean, median, mode, or a constant value such as 123.</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row7" class="row_heading level0 row7" >Annual avg. hours worked</th>
#       <td id="T_74c20_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_74c20_row7_col1" class="data row7 col1" >25.000000</td>
#       <td id="T_74c20_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_74c20_row7_col3" class="data row7 col3" >1380.000000</td>
#       <td id="T_74c20_row7_col4" class="data row7 col4" >2137.000000</td>
#       <td id="T_74c20_row7_col5" class="data row7 col5" >11 missing values. Impute them with mean, median, mode, or a constant value such as 123.</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row8" class="row_heading level0 row8" >Happiness levels(Country)</th>
#       <td id="T_74c20_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_74c20_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_74c20_row8_col2" class="data row8 col2" >NA</td>
#       <td id="T_74c20_row8_col3" class="data row8 col3" >3.570000</td>
#       <td id="T_74c20_row8_col4" class="data row8 col4" >7.800000</td>
#       <td id="T_74c20_row8_col5" class="data row8 col5" >Column has 1 outliers greater than upper bound (9.13) or lower than lower bound(3.91). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_74c20_level0_row9" class="row_heading level0 row9" >Outdoor activities(City)</th>
#       <td id="T_74c20_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_74c20_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_74c20_row9_col2" class="data row9 col2" >97</td>
#       <td id="T_74c20_row9_col3
# Number of All Scatter Plots = 15
# All Plots done
# Time to run AutoViz = 15 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
#          City        Rank  Sunshine hours(City)  \
# 0         Amsterdam    1          1858.0
# 1            Sydney    2          2636.0
# 2            Vienna    3          1884.0
# 3         Stockholm    4          1821.0
# 4        Copenhagen    5          1630.0
# 5          Helsinki    6          1662.0
# 6           Fukuoka    7          2769.0
# 7            Berlin    8          1626.0
# 8         Barcelona    9          2591.0
# 9         Vancouver   10          1938.0
# 10        Melbourne   11          2363.0
# 11          Beijing   12          2671.0
# 12          Bangkok   13          2624.0
# 13     Buenos Aires   14          2525.0
# 14          Toronto   15          2066.0
# 15           Madrid   16          2769.0
# 16          Jakarta   17          2983.0
# 17            Seoul   18          2066.0
# 18        Frankfurt   19          1662.0
# 19           Geneva   20             NaN
# 20         Tel Aviv   21          3311.0
# 21         Istanbul   22          2218.0
# 22            Cairo   23          3542.0
# 23           Taipei   24          1405.0
# 24      Los Angeles   25          3254.0
# 25           Mumbai   26          2584.0
# 26           Boston   27          2634.0
# 27           Dublin   28          1453.0
# 28            Tokyo   29          1877.0
# 29          Chicago   30          2508.0
# 30        Hong Kong   31          1836.0
# 31         Shanghai   32          1776.0
# 32         Brussels   33          1546.0
# 33    San Francisco   34          3062.0
# 34            Paris   35          1662.0
# 35        Sao Paulo   36          2003.0
# 36           Zurich   37          1566.0
# 37           London   38          1633.0
# 38     Johannesburg   39          3124.0
# 39            Milan   40          1915.0
# 40  Washington D.C.   41          2528.0
# 41         New York   42          2535.0
# 42           Moscow   43          1901.0
# 43      Mexico City   44          2555.0
#
#    Cost of a bottle of water(City) Obesity levels(Country)  \
# 0                1.92                        20.40
# 1                1.48                        29.00
# 2                1.94                        20.10
# 3                1.72                        20.60
# 4                2.19                        19.70
# 5                1.60                        22.20
# 6                0.78                         4.30
# 7                1.55                        22.30
# 8                1.19                        23.80
# 9                1.08                        29.40
# 10               1.57                        29.00
# 11               0.26                         6.20
# 12               0.22                        10.00
# 13               0.57                        28.30
# 14               1.09                        29.40
# 15               1.30                        23.80
# 16               0.21                         6.90
# 17               0.59                         4.70
# 18               1.95                        22.30
# 19               2.62                        19.50
# 20               1.63                        26.10
# 21               0.15                        32.10
# 22               0.16                        32.00
# 23               0.57                         6.20
# 24               1.52                        36.20
# 25               0.15                         3.90
# 26               1.39                        36.20
# 27               1.40                        25.30
# 28               0.76                         4.30
# 29               1.20                        36.20
# 30               0.75                         6.20
# 31               0.29                         6.20
# 32               2.11                        22.10
# 33               1.60                        36.20
# 34               1.95                        21.60
# 35               0.44                        22.10
# 36               3.20                        19.50
# 37               1.16                        27.80
# 38               0.59                        28.30
# 39               1.15                        19.90
# 40               1.45                        36.20
# 41               1.32                        36.20
# 42               0.41                        23.10
# 43               0.45                        28.90
#
#     Life expectancy(years) (Country)  Pollution(Index score) (City)  \
# 0                 81.2                            30.93
# 1                 82.1                            26.86
# 2                 81.0                            17.33
# 3                 81.8                            19.63
# 4                 79.8                            21.24
# 5                 80.4                            13.08
# 6                 83.2                              NaN
# 7                 80.6                            39.41
# 8                 82.2                            65.19
# 9                 81.7                            24.26
# 10                82.1                            25.90
# 11                75.4                            85.43
# 12                74.1                            76.64
# 13                75.9                            52.64
# 14                81.7                            37.83
# 15                82.2                            52.68
# 16                68.5                            84.39
# 17                81.3                            57.82
# 18                80.6                            37.78
# 19                82.6                            27.25
# 20                81.9                            47.28
# 21                74.7                            69.49
# 22                70.7                            91.74
# 23                75.4                            49.32
# 24                78.8                            66.07
# 25                67.3                            82.84
# 26                78.8                            27.03
# 27                80.5                            40.07
# 28                83.2                            42.84
# 29                78.8                            43.33
# 30                75.4                            67.46
# 31                75.4                            77.40
# 32                80.4                            62.67
# 33                78.8                            47.36
# 34                81.8                            65.10
# 35                73.9                            79.78
# 36                82.6                            17.31
# 37                80.4                            58.91
# 38                56.3                            61.83
# 39                82.7                            67.19
# 40                78.8                            39.18
# 41                78.8                            57.36
# 42                69.5                            57.63
# 43                76.4                            82.78
#
#     Annual avg. hours worked  Happiness levels(Country)  \
# 0            1434.0                     7.44
# 1            1712.0                     7.22
# 2            1501.0                     7.29
# 3            1452.0                     7.35
# 4            1380.0                     7.64
# 5            1540.0                     7.80
# 6            1644.0                     5.87
# 7            1386.0                     7.07
# 8            1686.0                     6.40
# 9            1670.0                     7.23
# 10           1712.0                     7.22
# 11              NaN                     5.12
# 12              NaN                     5.99
# 13              NaN                     5.97
# 14           1670.0                     7.23
# 15           1686.0                     6.40
# 16              NaN                     5.28
# 17           1967.0                     5.87
# 18           1386.0                     7.07
# 19           1557.0                     7.56
# 20           1898.0                     7.12
# 21           1832.0                     5.13
# 22              NaN                     4.15
# 23              NaN                     5.12
# 24           1779.0                     6.94
# 25              NaN                     3.57
# 26           1779.0                     6.94
# 27           1772.0                     7.09
# 28           1644.0                     5.87
# 29           1779.0                     6.94
# 30              NaN                     5.51
# 31              NaN                     5.12
# 32           1583.0                     6.86
# 33           1779.0                     6.94
# 34           1505.0                     6.66
# 35              NaN                     6.37
# 36           1557.0                     7.56
# 37           1538.0                     7.16
# 38              NaN                     4.81
# 39           1718.0                     6.38
# 40           1779.0                     6.94
# 41           1779.0                     6.94
# 42           1965.0                     5.54
# 43           2137.0                     6.46
#
#     Outdoor activities(City)  Number of take out places(City)  \
# 0              422                         1048
# 1              406                         1103
# 2              132                         1008
# 3              129                          598
# 4              154                          523
# 5              113                          309
# 6               35                          539
# 7              254                         1729
# 8              585                         2344
# 9              218                          788
# 10             243                          813
# 11             223                          261
# 12             377                         1796
# 13             246                         1435
# 14             174                         1656
# 15             216                         2491
# 16             114                          833
# 17             144                          389
# 18              23                          551
# 19              44                          444
# 20             139                          420
# 21             419                          934
# 22             323                          250
# 23             134                          717
# 24             223                         1439
# 25             187                         1183
# 26              88                          588
# 27             159                          659
# 28             387                         5802
# 29             171                         1320
# 30             277                         1257
# 31             108                          346
# 32              55                          988
# 33             242                         1031
# 34             331                         4363
# 35             158                         3355
# 36              69                          538
# 37             433                         6417
# 38             194                          492
# 39             110                         2396
# 40              83                          744
# 41             359                         3081
# 42             322                         3206
# 43             192                         1313
#
#    Cost of a monthly gym membership(City)
# 0                   34.90
# 1                   41.66
# 2                   25.74
# 3                   37.31
# 4                   32.53
# 5                   35.23
# 6                   55.87
# 7                   26.11
# 8                   37.80
# 9                   31.04
# 10                  36.89
# 11                  38.62
# 12                  50.03
# 13                  22.45
# 14                  32.64
# 15                  34.54
# 16                  29.94
# 17                  43.03
# 18                  39.01
# 19                  70.00
# 20                  58.31
# 21                  16.97
# 22                  23.25
# 23                  34.76
# 24                  32.00
# 25                  19.54
# 26                  46.27
# 27                  37.35
# 28                  70.82
# 29                  41.14
# 30                  57.95
# 31                  44.68
# 32                  25.34
# 33                  65.13
# 34                  35.93
# 35                  16.07
# 36                  73.11
# 37                  42.71
# 38                  24.28
# 39                  53.49
# 40                  65.99
# 41                  64.66
# 42                  31.40
# 43                  41.99

# %% [markdown]
# #### <b>3)MULTIVARIATE ANALYSIS

# %%
# ploting pair plot for multivariate analysis
sns.pairplot(data=data, hue='Life expectancy(years) (Country)', palette='husl')
plt.show()

# %% [markdown]
# ## <b>DATA PREPROCESSING / FEATURE ENGINEARING

# %% [markdown]
# #### <b>1) CHECK MISSING VALUE

# %%
data.isnull().sum()
# Out:
# City                                       0
# Rank                                       0
# Sunshine hours(City)                       1
# Cost of a bottle of water(City)            0
# Obesity levels(Country)                    0
# Life expectancy(years) (Country)           0
# Pollution(Index score) (City)              1
# Annual avg. hours worked                  11
# Happiness levels(Country)                  0
# Outdoor activities(City)                   0
# Number of take out places(City)            0
# Cost of a monthly gym membership(City)     0
# dtype: int64

# %% [markdown]
# #### <b>2) CHECKING THE DISTRIBUTION BEFORE VALUE IMPLUTATION

# %%
data1 = data[['Sunshine hours(City)','Cost of a bottle of water(City)','Obesity levels(Country)',
              'Life expectancy(years) (Country)','Pollution(Index score) (City)','Annual avg. hours worked',
              'Happiness levels(Country)','Outdoor activities(City)','Number of take out places(City)',
              'Cost of a monthly gym membership(City)']]

# %%
plt.figure(figsize=(20,25))
plotno=1

for column in data1:
    if plotno<+15:
        plt.subplot(4,3,plotno)
        sns.distplot(data1[column])
        plt.xlabel(column)
    plotno+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### <b>IMPUTE MISSING VALUES

# %%
data.loc[data['Sunshine hours(City)'].isnull()==True,'Sunshine hours(City)']=data['Sunshine hours(City)'].median()
data.loc[data['Pollution(Index score) (City)'].isnull()==True,'Pollution(Index score) (City)']=data['Pollution(Index score) (City)'].median()
data.loc[data['Annual avg. hours worked'].isnull()==True,'Annual avg. hours worked']=data['Annual avg. hours worked'].median()

# %% [markdown]
# ##### <b>CHECK MISSING VALUES

# %%
data.isnull().sum()
# Out:
# City                                      0
# Rank                                      0
# Sunshine hours(City)                      0
# Cost of a bottle of water(City)           0
# Obesity levels(Country)                   0
# Life expectancy(years) (Country)          0
# Pollution(Index score) (City)             0
# Annual avg. hours worked                  0
# Happiness levels(Country)                 0
# Outdoor activities(City)                  0
# Number of take out places(City)           0
# Cost of a monthly gym membership(City)    0
# dtype: int64

# %% [markdown]
# #### <b>3) CHANGING DATA TYPE

# %%
data.astype({'Sunshine hours(City)':'float64','Cost of a bottle of water(City)':'float64',
             'Obesity levels(Country)':'float64','Annual avg. hours worked':'float64',
            'Pollution(Index score) (City)':'float64','Cost of a monthly gym membership(City)':'float64'}).dtypes
# Out:
# City                                       object
# Rank                                        int64
# Sunshine hours(City)                      float64
# Cost of a bottle of water(City)           float64
# Obesity levels(Country)                   float64
# Life expectancy(years) (Country)          float64
# Pollution(Index score) (City)             float64
# Annual avg. hours worked                  float64
# Happiness levels(Country)                 float64
# Outdoor activities(City)                    int64
# Number of take out places(City)             int64
# Cost of a monthly gym membership(City)    float64
# dtype: object

# %% [markdown]
# #### <b>4) OUTLIER HANDLING

# %%
box = data[['Sunshine hours(City)','Pollution(Index score) (City)',
           'Annual avg. hours worked','Happiness levels(Country)',
           'Outdoor activities(City)','Number of take out places(City)']]

# %%
plt.figure(figsize=(20,15))
plotno=1
for column in box:
    if plotno<16:
        plt.subplot(3,3,plotno)
        sns.boxplot(box[column])
        plt.xlabel(column,fontsize=20)
        plotno+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# <b>1) SUNSHINE HOURS CITY (IQR)

# %%
#  Annual avg. hours worked feature small right side skewed (use iqr)
from scipy import stats

iqr = stats.iqr(data['Annual avg. hours worked'],interpolation='midpoint')
print(iqr)
# Out:
# 205.5

# %%
# min max limit calculation
Q1 = data['Annual avg. hours worked'].quantile(0.25)  # first quantile
Q3 = data['Annual avg. hours worked'].quantile(0.75)  # third quantile

# %%
min_limit = Q1 - 1.5*iqr
print('minimum limit',min_limit)
# Out:
# minimum limit 1268.25

# %%
max_limit = Q3 + 1.5*iqr
print('maximum limit',max_limit)
# Out:
# maximum limit 2082.0

# %%
# filtering the data
data.loc[data['Annual avg. hours worked']<min_limit]
# Out:
# Empty DataFrame
# Columns: [City, Rank, Sunshine hours(City), Cost of a bottle of water(City), Obesity levels(Country), Life expectancy(years) (Country), Pollution(Index score) (City), Annual avg. hours worked, Happiness levels(Country), Outdoor activities(City), Number of take out places(City), Cost of a monthly gym membership(City)]
# Index: []

# %%
data.loc[data['Annual avg. hours worked']>max_limit]
## So outliers are less than 5% so imputation are required
# Out:
#        City      Rank  Sunshine hours(City) Cost of a bottle of water(City)  \
# 43  Mexico City   44          2555.0                      0.45
#
#    Obesity levels(Country)  Life expectancy(years) (Country)  \
# 43           28.90                        76.4
#
#     Pollution(Index score) (City)  Annual avg. hours worked  \
# 43              82.78                       2137.0
#
#     Happiness levels(Country)  Outdoor activities(City)  \
# 43            6.46                        192
#
#     Number of take out places(City) Cost of a monthly gym membership(City)
# 43               1313                                41.99

# %%
# impute outlier with median
data.loc[data['Annual avg. hours worked'] > max_limit,'Annual avg. hours worked']=np.median(data['Annual avg. hours worked'])

# %%
sns.boxplot(data['Annual avg. hours worked'])
plt.show()

# %% [markdown]
# <b>2) HAPPINESS LEVEL (COUNTRY) (IQR)

# %%
# use iqr beacuse of data are skewed left
iqr = stats.iqr(data['Happiness levels(Country)'],interpolation='midpoint')
print(iqr)
# Out:
# 1.3199999999999994

# %%
Q1 = data['Happiness levels(Country)'].quantile(0.25) # first quantile
Q3 = data['Happiness levels(Country)'].quantile(0.75) # third quantile

# %%
### getting the limits
min_limit = Q1 - 1.5*iqr
print('minimum limit',min_limit)
# Out:
# minimum limit 3.890000000000001

# %%
max_limit = Q3 + 1.5*iqr
print('maximum limit',max_limit)
# Out:
# maximum limit 9.155

# %%
### filtering the data
data.loc[data['Happiness levels(Country)'] < min_limit]
# Out:
#      City   Rank  Sunshine hours(City) Cost of a bottle of water(City)  \
# 25  Mumbai   26          2584.0                      0.15
#
#    Obesity levels(Country)  Life expectancy(years) (Country)  \
# 25           3.90                         67.3
#
#     Pollution(Index score) (City)  Annual avg. hours worked  \
# 25              82.84                       1686.0
#
#     Happiness levels(Country)  Outdoor activities(City)  \
# 25            3.57                        187
#
#     Number of take out places(City) Cost of a monthly gym membership(City)
# 25               1183                                19.54

# %%
data.loc[data['Happiness levels(Country)'] > max_limit]
# Out:
# Empty DataFrame
# Columns: [City, Rank, Sunshine hours(City), Cost of a bottle of water(City), Obesity levels(Country), Life expectancy(years) (Country), Pollution(Index score) (City), Annual avg. hours worked, Happiness levels(Country), Outdoor activities(City), Number of take out places(City), Cost of a monthly gym membership(City)]
# Index: []

# %%
data.loc[data['Happiness levels(Country)'] < min_limit,'Happiness levels(Country)']=np.median(data['Happiness levels(Country)'])

# %%
sns.boxplot(data['Happiness levels(Country)']) ## outlier removed
plt.show()

# %% [markdown]
# <b>3) OUTDOOR ACTIVITIES (CITY) (IQR)

# %%
iqr = stats.iqr(data['Outdoor activities(City)'],interpolation='midpoint')
print(iqr)
# Out:
# 178.0

# %%
Q1 = data['Outdoor activities(City)'].quantile(0.25)  ## first quantile
Q3 = data['Outdoor activities(City)'].quantile(0.75)  ## third quantile

# %%
### getting max & min limit
min_limit = Q1 - 1.5*iqr
print('minimum limit',min_limit)
# Out:
# minimum limit -141.75

# %%
max_limit = Q3 + 1.5*iqr
print('maximum limit',max_limit)
# Out:
# maximum limit 555.25

# %%
# filtering the data
data.loc[data['Outdoor activities(City)'] < min_limit]
# Out:
# Empty DataFrame
# Columns: [City, Rank, Sunshine hours(City), Cost of a bottle of water(City), Obesity levels(Country), Life expectancy(years) (Country), Pollution(Index score) (City), Annual avg. hours worked, Happiness levels(Country), Outdoor activities(City), Number of take out places(City), Cost of a monthly gym membership(City)]
# Index: []

# %%
data.loc[data['Outdoor activities(City)'] > max_limit]
# Out:
#      City     Rank  Sunshine hours(City) Cost of a bottle of water(City)  \
# 8  Barcelona    9          2591.0                      1.19
#
#   Obesity levels(Country)  Life expectancy(years) (Country)  \
# 8           23.80                        82.2
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 8              65.19                       1686.0
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 8             6.4                        585
#
#    Number of take out places(City) Cost of a monthly gym membership(City)
# 8               2344                                37.80

# %%
data.loc[data['Outdoor activities(City)'] > max_limit,'Outdoor activities(City)']=np.median(data['Outdoor activities(City)'])

# %%
sns.boxplot(data['Outdoor activities(City)'])
plt.show()

# %% [markdown]
# <b>4) NUMBER OF TAKE OUT PLACES (CITY) (IQR)

# %%
iqr = stats.iqr(data['Number of take out places(City)'],interpolation='midpoint')
print(iqr)
# Out:
# 1147.5

# %%
Q1 = data['Number of take out places(City)'].quantile(0.25)  ## first quantile
Q3 =data['Number of take out places(City)'].quantile(0.75)   ## third quantile

# %%
## getting the maximum and minimum limit
min_limit = Q1 - 1.5*iqr
print('minimum limit',min_limit)
# Out:
# minimum limit -1173.25

# %%
max_limit = Q3 + 1.5*iqr
print('maximum limit',max_limit)
# Out:
# maximum limit 3395.5

# %%
# filtering the data
data.loc[data['Number of take out places(City)'] < min_limit]
# Out:
# Empty DataFrame
# Columns: [City, Rank, Sunshine hours(City), Cost of a bottle of water(City), Obesity levels(Country), Life expectancy(years) (Country), Pollution(Index score) (City), Annual avg. hours worked, Happiness levels(Country), Outdoor activities(City), Number of take out places(City), Cost of a monthly gym membership(City)]
# Index: []

# %%
data.loc[data['Number of take out places(City)'] > max_limit]
# Out:
#      City   Rank  Sunshine hours(City) Cost of a bottle of water(City)  \
# 28   Tokyo   29          1877.0                      0.76
# 34   Paris   35          1662.0                      1.95
# 37  London   38          1633.0                      1.16
#
#    Obesity levels(Country)  Life expectancy(years) (Country)  \
# 28            4.30                        83.2
# 34           21.60                        81.8
# 37           27.80                        80.4
#
#     Pollution(Index score) (City)  Annual avg. hours worked  \
# 28              42.84                       1644.0
# 34              65.10                       1505.0
# 37              58.91                       1538.0
#
#     Happiness levels(Country)  Outdoor activities(City)  \
# 28            5.87                       387.0
# 34            6.66                       331.0
# 37            7.16                       433.0
#
#     Number of take out places(City) Cost of a monthly gym membership(City)
# 28               5802                                70.82
# 34               4363                                35.93
# 37               6417                                42.71

# %%
data.loc[data['Number of take out places(City)'] > max_limit,'Number of take out places(City)']=np.median(data['Number of take out places(City)'])

# %%
### checking box plot
sns.boxplot(data['Number of take out places(City)'])
plt.show()

# %% [markdown]
# <b>Observation
# - Outliers are removed

# %% [markdown]
# #### <b>4) SCALING THE DATA

# %%
from sklearn.preprocessing import MinMaxScaler

scalar = MinMaxScaler()

data[['Sunshine hours(City)','Cost of a bottle of water(City)','Obesity levels(Country)','Life expectancy(years) (Country)',
     'Pollution(Index score) (City)','Annual avg. hours worked','Happiness levels(Country)',
      'Cost of a monthly gym membership(City)','Outdoor activities(City)'
      ,'Number of take out places(City)']] = scalar.fit_transform(data[['Sunshine hours(City)','Cost of a bottle of water(City)',
    'Obesity levels(Country)','Life expectancy(years) (Country)',
     'Pollution(Index score) (City)','Annual avg. hours worked','Happiness levels(Country)',
      'Cost of a monthly gym membership(City)','Outdoor activities(City)','Number of take out places(City)']])

data.head()
# Out:
#       City     Rank  Sunshine hours(City)  Cost of a bottle of water(City)  \
# 0   Amsterdam    1         0.211979                   0.580328
# 1      Sydney    2         0.576041                   0.436066
# 2      Vienna    3         0.224146                   0.586885
# 3   Stockholm    4         0.194665                   0.514754
# 4  Copenhagen    5         0.105288                   0.668852
#
#    Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0         0.510836                      0.925651
# 1         0.777090                      0.959108
# 2         0.501548                      0.918216
# 3         0.517028                      0.947955
# 4         0.489164                      0.873606
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 0            0.226926                     0.091993
# 1            0.175184                     0.565588
# 2            0.054030                     0.206133
# 3            0.083270                     0.122658
# 4            0.103738                     0.000000
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0          0.901370                   0.973171
# 1          0.841096                   0.934146
# 2          0.860274                   0.265854
# 3          0.876712                   0.258537
# 4          0.956164                   0.319512
#
#    Number of take out places(City)  Cost of a monthly gym membership(City)
# 0             0.257005                             0.330119
# 1             0.274718                             0.448633
# 2             0.244122                             0.169530
# 3             0.112077                             0.372370
# 4             0.087923                             0.288569

# %% [markdown]
# ## <b>FEATURE SELECTION

# %% [markdown]
# #### <b>1) REMOVE UNIQUE COLUMN

# %%
data.drop(['City','Rank'],axis=1,inplace=True)
data.head()
# Out:
#    Sunshine hours(City)  Cost of a bottle of water(City)  \
# 0        0.211979                   0.580328
# 1        0.576041                   0.436066
# 2        0.224146                   0.586885
# 3        0.194665                   0.514754
# 4        0.105288                   0.668852
#
#    Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0         0.510836                      0.925651
# 1         0.777090                      0.959108
# 2         0.501548                      0.918216
# 3         0.517028                      0.947955
# 4         0.489164                      0.873606
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 0            0.226926                     0.091993
# 1            0.175184                     0.565588
# 2            0.054030                     0.206133
# 3            0.083270                     0.122658
# 4            0.103738                     0.000000
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0          0.901370                   0.973171
# 1          0.841096                   0.934146
# 2          0.860274                   0.265854
# 3          0.876712                   0.258537
# 4          0.956164                   0.319512
#
#    Number of take out places(City)  Cost of a monthly gym membership(City)
# 0             0.257005                             0.330119
# 1             0.274718                             0.448633
# 2             0.244122                             0.169530
# 3             0.112077                             0.372370
# 4             0.087923                             0.288569

# %% [markdown]
# #### <b>2) CHECK CORRELATION

# %%
data2 = data[['Sunshine hours(City)','Cost of a bottle of water(City)','Obesity levels(Country)',
              'Life expectancy(years) (Country)','Pollution(Index score) (City)','Annual avg. hours worked',
              'Happiness levels(Country)','Cost of a monthly gym membership(City)']]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data2.corr(),annot=True,cmap='cool')
plt.show()

# %% [markdown]
# <b>Observation
# - No highly correlated feature in data.

# %%
data2.describe()
# Out:
#        Sunshine hours(City)  Cost of a bottle of water(City)  \
# count        44.000000                  44.000000
# mean          0.391564                   0.335544
# std           0.262715                   0.235620
# min           0.000000                   0.000000
# 25%           0.189401                   0.137705
# 50%           0.309312                   0.342623
# 75%           0.571596                   0.475410
# max           1.000000                   1.000000
#
#        Obesity levels(Country)  Life expectancy(years) (Country)  \
# count         44.000000                     44.000000
# mean           0.558050                      0.813197
# std            0.315655                      0.197188
# min            0.000000                      0.000000
# 25%            0.482972                      0.710037
# 50%            0.569659                      0.895911
# 75%            0.777090                      0.947955
# max            1.000000                      1.000000
#
#        Pollution(Index score) (City)  Annual avg. hours worked  \
# count            44.000000                    44.000000
# mean              0.484068                     0.487107
# std               0.274622                     0.234828
# min               0.000000                     0.000000
# 25%               0.292239                     0.334753
# 50%               0.502924                     0.521295
# 75%               0.677218                     0.598807
# max               1.000000                     1.000000
#
#        Happiness levels(Country)  Cost of a monthly gym membership(City)
# count          44.000000                         44.000000
# mean            0.646762                          0.426893
# std             0.243629                          0.263087
# min             0.000000                          0.000000
# 25%             0.471233                          0.267181
# 50%             0.758904                          0.372721
# 75%             0.828767                          0.545933
# max             1.000000                          1.000000

# %% [markdown]
# #### <b>3) CHECKING DUPLICATES

# %%
data.duplicated().sum() ## No duplicate in data
# Out:
# 0

# %% [markdown]
# #### <b>4) SAVE PREPROCESSING DATA

# %%
data.to_csv('preprocess.csv')

# %%
df  = pd.read_csv('preprocess.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Sunshine hours(City)  Cost of a bottle of water(City)  \
# 0       0            0.211979                   0.580328
# 1       1            0.576041                   0.436066
# 2       2            0.224146                   0.586885
# 3       3            0.194665                   0.514754
# 4       4            0.105288                   0.668852
#
#    Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0         0.510836                      0.925651
# 1         0.777090                      0.959108
# 2         0.501548                      0.918216
# 3         0.517028                      0.947955
# 4         0.489164                      0.873606
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 0            0.226926                     0.091993
# 1            0.175184                     0.565588
# 2            0.054030                     0.206133
# 3            0.083270                     0.122658
# 4            0.103738                     0.000000
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0          0.901370                   0.973171
# 1          0.841096                   0.934146
# 2          0.860274                   0.265854
# 3          0.876712                   0.258537
# 4          0.956164                   0.319512
#
#    Number of take out places(City)  Cost of a monthly gym membership(City)
# 0             0.257005                             0.330119
# 1             0.274718                             0.448633
# 2             0.244122                             0.169530
# 3             0.112077                             0.372370
# 4             0.087923                             0.288569

# %% [markdown]
# ## <b>MODEL CREATION

# %%
# Step:1 Define data
X = df.iloc[:,1:]
X.head()
# Out:
#    Sunshine hours(City)  Cost of a bottle of water(City)  \
# 0        0.211979                   0.580328
# 1        0.576041                   0.436066
# 2        0.224146                   0.586885
# 3        0.194665                   0.514754
# 4        0.105288                   0.668852
#
#    Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0         0.510836                      0.925651
# 1         0.777090                      0.959108
# 2         0.501548                      0.918216
# 3         0.517028                      0.947955
# 4         0.489164                      0.873606
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 0            0.226926                     0.091993
# 1            0.175184                     0.565588
# 2            0.054030                     0.206133
# 3            0.083270                     0.122658
# 4            0.103738                     0.000000
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0          0.901370                   0.973171
# 1          0.841096                   0.934146
# 2          0.860274                   0.265854
# 3          0.876712                   0.258537
# 4          0.956164                   0.319512
#
#    Number of take out places(City)  Cost of a monthly gym membership(City)
# 0             0.257005                             0.330119
# 1             0.274718                             0.448633
# 2             0.244122                             0.169530
# 3             0.112077                             0.372370
# 4             0.087923                             0.288569

# %%
# Step:2 Get K-value
plt.figure(figsize=(8,6)) ### create canvas
from sklearn.cluster import KMeans
wcss = []
for i in range(3,20):
    kmeans = KMeans(n_clusters=i,random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(3,20),wcss,c='k')
plt.xlabel('K-value')
plt.ylabel('wcss')
plt.show()

# %%
# Step:3 Initalize the cluster
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=9,random_state=45)

# %%
# Step:4 Fitting the data
model.fit(X)
# Out:
# KMeans(n_clusters=9, random_state=45)

# %%
# Step:5 Get labels
model.labels_
# Out:
# array([1, 1, 4, 4, 4, 4, 2, 1, 0, 1, 1, 2, 8, 6, 1, 0, 2, 2, 4, 7, 5, 6,
#        3, 2, 0, 2, 5, 1, 8, 5, 8, 2, 4, 5, 1, 6, 7, 1, 3, 0, 5, 5, 6, 0])

# %%
# Step:6 print dataset with labels
data['cluster'] = pd.DataFrame(model.labels_)

# %%
data.head()
# Out:
#    Sunshine hours(City)  Cost of a bottle of water(City)  \
# 0        0.211979                   0.580328
# 1        0.576041                   0.436066
# 2        0.224146                   0.586885
# 3        0.194665                   0.514754
# 4        0.105288                   0.668852
#
#    Obesity levels(Country)  Life expectancy(years) (Country)  \
# 0         0.510836                      0.925651
# 1         0.777090                      0.959108
# 2         0.501548                      0.918216
# 3         0.517028                      0.947955
# 4         0.489164                      0.873606
#
#    Pollution(Index score) (City)  Annual avg. hours worked  \
# 0            0.226926                     0.091993
# 1            0.175184                     0.565588
# 2            0.054030                     0.206133
# 3            0.083270                     0.122658
# 4            0.103738                     0.000000
#
#    Happiness levels(Country)  Outdoor activities(City)  \
# 0          0.901370                   0.973171
# 1          0.841096                   0.934146
# 2          0.860274                   0.265854
# 3          0.876712                   0.258537
# 4          0.956164                   0.319512
#
#    Number of take out places(City)  Cost of a monthly gym membership(City)  \
# 0             0.257005                             0.330119
# 1             0.274718                             0.448633
# 2             0.244122                             0.169530
# 3             0.112077                             0.372370
# 4             0.087923                             0.288569
#
#    cluster
# 0     1
# 1     1
# 2     4
# 3     4
# 4     4

# %%
# Step:7 Intalize centroid
model.cluster_centers_
# Out:
# array([[0.56705662, 0.31868852, 0.7003096 , 0.89814126, 0.6827104 ,
#         0.56388416, 0.64821918, 0.39780488, 0.56251208, 0.41889902],
#        [0.23865232, 0.43169399, 0.68489852, 0.93102024, 0.32707574,
#         0.37459777, 0.82100457, 0.65934959, 0.26988728, 0.3401122 ],
#        [0.42910622, 0.08430913, 0.04909332, 0.7031333 , 0.72333006,
#         0.57945972, 0.40039139, 0.27317073, 0.11585001, 0.38556902],
#        [0.90219934, 0.07377049, 0.8126935 , 0.26765799, 0.80987796,
#         0.52129472, 0.09041096, 0.57439024, 0.0389694 , 0.13490533],
#        [0.13843394, 0.57978142, 0.53457172, 0.90582404, 0.1975803 ,
#         0.15956843, 0.87260274, 0.1902439 , 0.1329576 , 0.28851099],
#        [0.63547029, 0.42021858, 0.94788442, 0.85563817, 0.38787185,
#         0.71351505, 0.77260274, 0.38373984, 0.3050993 , 0.71610566],
#        [0.35411792, 0.0795082 , 0.69659443, 0.6394052 , 0.65859395,
#         0.70229983, 0.4390411 , 0.64207317, 0.63848631, 0.09909712],
#        [0.19232569, 0.90491803, 0.48297214, 0.97769517, 0.11695906,
#         0.30153322, 0.93424658, 0.08170732, 0.07761675, 0.97273843],
#        [0.3309936 , 0.13989071, 0.09081527, 0.7905824 , 0.6259005 ,
#         0.49744463, 0.44931507, 0.7902439 , 0.35437466, 0.76314867]])

# %% [markdown]
# ## <b>MODEL EVALUATION

# %%
# Model evaluation matrices
label = model.labels_  ### create new veriable and assgin to labels
label
# Out:
# array([1, 1, 4, 4, 4, 4, 2, 1, 0, 1, 1, 2, 8, 6, 1, 0, 2, 2, 4, 7, 5, 6,
#        3, 2, 0, 2, 5, 1, 8, 5, 8, 2, 4, 5, 1, 6, 7, 1, 3, 0, 5, 5, 6, 0])

# %%
from sklearn.metrics import silhouette_score
silhou_score = silhouette_score(X,label)
silhou_score  # range of silhouette score -1 to +1
# Out:
# 0.21863589778198922

# %% [markdown]
# ## <b>MODEL SAVING

# %%
# Model saving using pickle
import pickle
file = open("kmeans_clustering_model.pkl","wb")
pickle.dump(model,file)

# %% [markdown]
# ## <b>Summary
# <b>
#
# - Cities with better lifestyle tend to have:
#     - Higher sunshine hours
#     - Lower pollution
#     - More outdoor activities
#     - Affordable gym memberships
#     - Higher happiness scores
#
# - Cities with lifestyle challenges show:
#     - High working hours
#     - High cost of basic amenities (water, gym)
#     - Low outdoor activity score
#     - Poor pollution index
#
# - Top lifestyle cities can be targeted for relocation, tourism, or wellness initiatives.
# - Some cities need lifestyle improvements, potential areas for government or private intervention.

# %% [markdown]
# ## <b>Conclusion
# <b>
#
# - The clustering successfully grouped cities into meaningful lifestyle segments using unsupervised learning.
# - These insights can be leveraged by:
#     - Individuals planning relocation.
#     - Governments or NGOs promoting wellness.
#     - Companies targeting healthy-lifestyle customers.
# - The methodology can be reused or enhanced with new data from future years for trend analysis.

# %% [markdown]
# # <b>END OF PROJECT
# <b> Siddheshwar Koli
